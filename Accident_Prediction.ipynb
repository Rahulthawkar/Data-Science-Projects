# %%
import pandas as pd
df = pd.read_csv('gsd.csv')
df
# Out:
#      road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0        rural          3       0.38           35  daylight   foggy
# 1      highway          2       0.50           60  daylight   clear
# 2        rural          2       0.95           60  daylight   clear
# 3        rural          4       0.76           25  daylight   rainy
# 4      highway          1       0.43           60  daylight   foggy
# ...        ...        ...        ...          ...       ...     ...
# 9995     rural          4       0.39           35  daylight   rainy
# 9996   highway          2       0.15           35  daylight   foggy
# 9997     urban          3       0.62           35  daylight   clear
# 9998     urban          1       0.60           45  daylight   clear
# 9999     rural          2       0.44           70     night   foggy
#
#       road_signs_present  public_road time_of_day  holiday  school_season  \
# 0                   True         True     evening     True           True
# ...

# %% [markdown]
# Here, I use the breast cancer dataset which can be obtained from sklearn.datasets. It is also available in Kaggle.

# %%
df.describe()
# Out:
#           num_lanes     curvature   speed_limit  num_reported_accidents  \
# count  10000.000000  10000.000000  10000.000000            10000.000000
# mean       2.500200      0.499122     47.388000                1.494500
# std        1.123088      0.288357     16.363197                1.209263
# min        1.000000      0.000000     25.000000                0.000000
# 25%        1.000000      0.250000     35.000000                1.000000
# 50%        2.000000      0.500000     45.000000                1.000000
# 75%        4.000000      0.750000     60.000000                2.000000
# max        4.000000      1.000000     70.000000                8.000000
#
#        accident_risk
# count   10000.000000
# mean        0.386417
# std         0.181459
# min         0.000000
# 25%         0.250000
# 50%         0.380000
# 75%         0.510000
# max         1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   road_type               10000 non-null  object
#  1   num_lanes               10000 non-null  int64
#  2   curvature               10000 non-null  float64
#  3   speed_limit             10000 non-null  int64
#  4   lighting                10000 non-null  object
#  5   weather                 10000 non-null  object
#  6   road_signs_present      10000 non-null  bool
#  7   public_road             10000 non-null  bool
#  8   time_of_day             10000 non-null  object
#  9   holiday                 10000 non-null  bool
#  10  school_season           10000 non-null  bool
#  11  num_reported_accidents  10000 non-null  int64
#  12  accident_risk           10000 non-null  float64
# dtypes: bool(4), float64(2), int64(3), object(4)
# memory usage: 742.3+ KB

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.isnull().sum()
# Out:
# road_type                 0
# num_lanes                 0
# curvature                 0
# speed_limit               0
# lighting                  0
# weather                   0
# road_signs_present        0
# public_road               0
# time_of_day               0
# holiday                   0
# school_season             0
# num_reported_accidents    0
# accident_risk             0
# dtype: int64

# %%
df.head()
# Out:
#   road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0     rural          3       0.38           35  daylight   foggy
# 1   highway          2       0.50           60  daylight   clear
# 2     rural          2       0.95           60  daylight   clear
# 3     rural          4       0.76           25  daylight   rainy
# 4   highway          1       0.43           60  daylight   foggy
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0                True         True     evening     True           True
# 1                True        False   afternoon    False           True
# 2                True         True   afternoon     True          False
# 3               False        False   afternoon    False           True
# 4               False        False     evening     True           True
#
#    num_reported_accidents  accident_risk
# 0                       1           0.20
# 1                       1           0.36
# ...

# %%
df.nunique()
# Out:
# road_type                   3
# num_lanes                   4
# curvature                 101
# speed_limit                 5
# lighting                    3
# weather                     3
# road_signs_present          2
# public_road                 2
# time_of_day                 3
# holiday                     2
# school_season               2
# num_reported_accidents      9
# accident_risk              98
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['road_type',
#  'num_lanes',
#  'curvature',
#  'speed_limit',
#  'lighting',
#  'weather',
#  'road_signs_present',
#  'public_road',
#  'time_of_day',
#  'holiday',
#  'school_season',
#  'num_reported_accidents',
#  'accident_risk']

# %%
df.head()
# Out:
#   road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0     rural          3       0.38           35  daylight   foggy
# 1   highway          2       0.50           60  daylight   clear
# 2     rural          2       0.95           60  daylight   clear
# 3     rural          4       0.76           25  daylight   rainy
# 4   highway          1       0.43           60  daylight   foggy
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0                True         True     evening     True           True
# 1                True        False   afternoon    False           True
# 2                True         True   afternoon     True          False
# 3               False        False   afternoon    False           True
# 4               False        False     evening     True           True
#
#    num_reported_accidents  accident_risk
# 0                       1           0.20
# 1                       1           0.36
# ...

# %% [markdown]
#   Feature Scaling

# %%
# %pip install scikit-learn
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
col = ['road_type','lighting','weather',
       'road_signs_present','public_road',
       'time_of_day','holiday','school_season']

# Use one-hot encoding for categorical variables if not already done
if set(col).issubset(df.columns):
    df = pd.get_dummies(df, columns=col, drop_first=True)

# Check the transformed dataframe
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 6
#       1 col = ['road_type','lighting','weather',
#       2        'road_signs_present','public_road',
#       3        'time_of_day','holiday','school_season']
#       5 # Use one-hot encoding for categorical variables
# ----> 6 df = pd.get_dummies(df, columns=col, drop_first=True)
#       8 # Check the transformed dataframe
#       9 df.head()
#
# File c:\Users\rahul\OneDrive\Attachments\Documents\Desktop\PYTHON PROGRAMMING\.venv\Lib\site-packages\pandas\core\reshape\encoding.py:170, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     168     raise TypeError("Input must be a list-like for parameter `columns`")
#     169 else:
# --> 170     data_to_encode = data[columns]
#     172 # validate prefixes and separator to avoid silently dropping cols
# ...

# %%
x= df.drop('accident_risk',axis=1).values
y= df['accident_risk'].values

# %%
y.shape
# Out:
# (10000,)

# %%
x.shape
# Out:
# (10000, 12)

# %% [markdown]
# ### Now we split our dataset as train set and test set.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                   test_size=0.20, random_state=0)

# %% [markdown]
# Feature Scalingj

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)

# %%
x_test = sc.transform(x_test)

# %%
x_train.shape
# Out:
# (8000, 12)

# %%
x_test.shape
# Out:
# (2000, 12)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0.25176351, 0.28117634, 0.41829611, ..., 0.18572345, 0.80031738,
#        0.61191456], shape=(2000,))

# %%
import matplotlib.pyplot as plt
plt.plot(y_test, color='blue', label='Actual')
plt.plot(y_pred, color='red', label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# Evaluation Techniques

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, y_pred)  
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Absolute Error: 0.057414247673013896
# Mean Squared Error: 0.005135877489212531
# R^2 Score: 0.841791398154315
